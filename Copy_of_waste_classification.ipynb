# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/garythung/trashnet.git
# Out:
# Cloning into 'trashnet'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 45 (delta 6), reused 0 (delta 0), pack-reused 33 (from 1)
# Receiving objects: 100% (45/45), 40.64 MiB | 33.37 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
import shutil
shutil.move("trashnet/data/dataset-resized", "dataset")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.11/shutil.py in move(src, dst, copy_function)
#     852     try:
# --> 853         os.rename(src, real_dst)
#     854     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'trashnet/data/dataset-resized' -> 'dataset'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4282e29802c5> in <cell line: 0>()
#       1 import shutil
# ----> 2 shutil.move("trashnet/data/dataset-resized", "dataset")
#
# /usr/lib/python3.11/shutil.py in move(src, dst, copy_function)
#     871             rmtree(src)
#     872         else:
# --> 873             copy_function(src, real_dst)
#     874             os.unlink(src)
#     875     return real_dst
#
# ...

# %%
from google.colab import files
files.upload()  # Manually upload kaggle.json
# Out:
#      <input type="file" id="files-b5e93065-7666-4aee-bf64-55b7f82da10c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5e93065-7666-4aee-bf64-55b7f82da10c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d asdasdasasdas/garbage-classification
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/asdasdasasdas/garbage-classification
# License(s): copyright-authors
# ...
#  84% 69.0M/82.0M [00:00<00:00, 112MB/s]
# 100% 82.0M/82.0M [00:00<00:00, 115MB/s]

# %%
import zipfile
import os

# Extract dataset
zip_path = "garbage-classification.zip"
extract_path = "dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Verify extracted dataset
print("Categories:", os.listdir(extract_path))
# Out:
# Categories: ['Garbage classification', 'zero-indexed-files.txt', 'one-indexed-files-notrash_train.txt', 'garbage classification', 'one-indexed-files-notrash_test.txt', 'one-indexed-files-notrash_val.txt', 'one-indexed-files.txt']

# %%
# verify that the dataset is there
import os
data_dir = "dataset/Garbage classification"
print("Categories:", os.listdir(data_dir))  # Should show ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']
# Out:
# Categories: ['Garbage classification']

# %%
# AI-Powered Waste Classification using CNN
# Implemented with a Streamlit Dashboard

## 1️⃣ Load & Preprocess Dataset

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import os
from tensorflow.keras.preprocessing import image_dataset_from_directory

# dataset = image_dataset_from_directory(data_dir, batch_size=32, image_size=(180, 180))
# class_names = dataset.class_names
# print("Classes:", class_names)


# Load dataset (assuming TrashNet images are in 'dataset' folder)
data_dir = 'dataset/'
batch_size = 32
img_height = 180
img_width = 180

dataset = image_dataset_from_directory(data_dir, batch_size=batch_size, image_size=(img_height, img_width))
class_names = dataset.class_names

# Split into train and test datasets
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_ds = dataset.take(train_size)
test_ds = dataset.skip(train_size)

## 2️⃣ Build & Train CNN Model

model = keras.Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(16, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(len(class_names), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train Model
model.fit(train_ds, epochs=10, validation_data=test_ds)

# Save Model
model.save('waste_classifier.h5')
# Out:
# Found 5054 files belonging to 2 classes.
# Epoch 1/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.4981 - loss: 0.9197 - val_accuracy: 0.4912 - val_loss: 0.6933
# Epoch 2/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.5014 - loss: 0.6932 - val_accuracy: 0.4971 - val_loss: 0.6932
# Epoch 3/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.5040 - loss: 0.6932 - val_accuracy: 0.4912 - val_loss: 0.6933
# Epoch 4/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.4970 - loss: 0.6932 - val_accuracy: 0.4873 - val_loss: 0.6933
# Epoch 5/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.5036 - loss: 0.6932 - val_accuracy: 0.4873 - val_loss: 0.6932
# Epoch 6/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.5041 - loss: 0.6932 - val_accuracy: 0.4922 - val_loss: 0.6934
# Epoch 7/10
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.5058 - loss: 0.6931 - val_accuracy: 0.4902 - val_loss: 0.6934
# Epoch 8/10
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# Move notebook from Google Drive to Colab working directory
# !cp "/content/drive/MyDrive/Colab Notebooks/Copy of waste_classification.ipynb" .
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
files.download("Copy of waste_classification.ipynb")

# %%
# !git clone https://github.com/Tihetna1891/AI-Waste-Management.git
# Out:
# Cloning into 'AI-Waste-Management'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), done.

# %%
# !mv Copy_of_waste_classification.ipynb AI-Waste-Management/
# Out:
# mv: cannot stat 'Copy_of_waste_classification.ipynb': No such file or directory
